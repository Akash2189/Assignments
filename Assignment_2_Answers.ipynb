# %% [markdown]
# ![A2-1-2.jpg](attachment:A2-1-2.jpg)

# %% [markdown]
# ![A2_3_5.jpg](attachment:A2_3_5.jpg)

# %% [markdown]
# ![A2-6..jpg](attachment:A2-6..jpg)

# %% [markdown]
# ![A2_7.jpg](attachment:A2_7.jpg)
